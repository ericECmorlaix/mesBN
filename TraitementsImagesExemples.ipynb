# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
rouge = plt.imread("img/mesange.jpg")
rouge.shape
# Out:
# (426, 640, 3)

# %%
rouge = plt.imread("img/mesange.jpg")
rouge[:,:,1]=0
rouge[:,:,2]=0
plt.imshow(rouge)
plt.show()

# %%
vert = plt.imread("img/mesange.jpg")
vert[:,:,0]=0
vert[:,:,2]=0
plt.imshow(vert)
plt.show()

# %%
bleu = plt.imread("img/mesange.jpg")
bleu[:,:,0]=0
bleu[:,:,1]=0
plt.imshow(bleu)
plt.show()

# %%
cyan = plt.imread("img/mesange.jpg")
cyan[:,:,0]=0
plt.imshow(cyan)
plt.show()

# %%
magenta = plt.imread("img/mesange.jpg")
magenta[:,:,1]=0
plt.imshow(magenta)
plt.show()

# %%
jaune = plt.imread("img/mesange.jpg")
jaune[:,:,2]=0
plt.imshow(jaune)
plt.show()

# %%
rouge = plt.imread("img/mesange.jpg")
rouge[:,:,1]=255
rouge[:,:,2]=255
plt.imshow(rouge)
plt.show()

# %%
rouge = plt.imread("img/mesange.jpg")
rouge[:,:,1]=255
rouge[:,:,2]=255
fig = plt.figure()
a = fig.add_subplot(1, 2, 1)
imgplot = plt.imshow(rouge)
a.set_title('Before')
plt.colorbar(ticks=[0.1, 0.3, 0.5, 0.7], orientation='horizontal')
a = fig.add_subplot(1, 2, 2)
imgplot = plt.imshow(rouge)
imgplot.set_clim(0.0, 0.7)
a.set_title('After')
plt.colorbar(ticks=[0.1, 0.3, 0.5, 0.7], orientation='horizontal')

# %%
vert = plt.imread("img/mesange.jpg")
vert[:,:,0]=255
vert[:,:,2]=255
plt.imshow(vert)
plt.show()

# %%
bleu = plt.imread("img/mesange.jpg")
bleu[:,:,0]=255
bleu[:,:,1]=255
plt.imshow(bleu)
plt.show()

# %%
cyan = plt.imread("img/mesange.jpg")
cyan[:,:,0]=255
plt.imshow(cyan)
plt.show()

# %%
magenta = plt.imread("img/mesange.jpg")
magenta[:,:,1]=255
plt.imshow(magenta)
plt.show()

# %%
jaune = plt.imread("img/mesange.jpg")
jaune[:,:,2]=255
plt.imshow(jaune)
plt.show()

# %%
gris = plt.imread("img/mesange.jpg")
for i in range (426):
    for j in range (640):
        gris[i,j,0]=gris[i,j,1]
        gris[i,j,2]=gris[i,j,1]
plt.imshow(gris)
plt.show()        
plt.imsave("toto.png", gris)

# %% [markdown]
# https://matplotlib.org/examples/color/colormaps_reference.html

# %%
test = plt.imread("img/mesange.jpg")
sortie = test[:,:,0]
plt.imshow(sortie,cmap="terrain")
plt.colorbar()
plt.show()

# %%
gris = plt.imread("img/mesange.jpg")
for i in range (426):
    for j in range (640):
        gris[i,j,0]=gris[i,j,1]
        gris[i,j,2]=gris[i,j,1]
plt.imshow(gris, interpolation="nearest")
plt.show()

# %%
import matplotlib.image as mpimg

# %%
mpimg.thumbnail
